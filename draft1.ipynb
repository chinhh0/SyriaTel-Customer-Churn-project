# %% [markdown]
# # Import and clean data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('churn_telecom.csv')

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
df.shape
# Out:
# (3333, 21)

# %%
df.isna().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
df.churn.value_counts()
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %%
df.columns=df.columns.map(lambda x : x.replace(' ', '_'))

# %%
df.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'phone_number',
#        'international_plan', 'voice_mail_plan', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'customer_service_calls', 'churn'],
#       dtype='object')

# %%
trans_col=['international_plan', 'voice_mail_plan',]

# %%
df.head()
# Out:
#   state  account_length  area_code phone_number international_plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %%
for col in df[trans_col]:
    df[col]=df[col].map({'yes':1, 'no':0})

# %%
df[trans_col]
# Out:
#       international_plan  voice_mail_plan
# 0                      0                1
# 1                      0                1
# 2                      0                0
# 3                      1                0
# 4                      1                0
# ...                  ...              ...
# 3328                   0                1
# 3329                   0                0
# 3330                   0                0
# 3331                   1                0
# 3332                   0                1
#
# [3333 rows x 2 columns]

# %%
df.head()
# Out:
#   state  account_length  area_code phone_number  international_plan  \
# 0    KS             128        415     382-4657                   0
# 1    OH             107        415     371-7191                   0
# 2    NJ             137        415     358-1921                   0
# 3    OH              84        408     375-9999                   1
# 4    OK              75        415     330-6626                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %%
df.describe()
# Out:
#        account_length    area_code  international_plan  voice_mail_plan  \
# count     3333.000000  3333.000000         3333.000000      3333.000000
# mean       101.064806   437.182418            0.096910         0.276628
# std         39.822106    42.371290            0.295879         0.447398
# min          1.000000   408.000000            0.000000         0.000000
# 25%         74.000000   408.000000            0.000000         0.000000
# 50%        101.000000   415.000000            0.000000         0.000000
# 75%        127.000000   510.000000            0.000000         1.000000
# max        243.000000   510.000000            1.000000         1.000000
#
#        number_vmail_messages  total_day_minutes  total_day_calls  \
# count            3333.000000        3333.000000      3333.000000
# mean                8.099010         179.775098       100.435644
# std                13.688365          54.467389        20.069084
# ...

# %%
#df=df.drop(['state', 'account_length', 'area_code', 'phone_number'], axis=1)

# %%
len(df.state.value_counts())
# Out:
# 51

# %%
#make a table to see relationship between steat vs churn
state_rate=pd.crosstab(df.state, df.churn)
state_rate.head()
# Out:
# churn   0   1
# state
# AK     49   3
# AL     72   8
# AR     44  11
# AZ     60   4
# CA     25   9

# %%
rate=pd.crosstab(df.state, df.churn, normalize='index')
rate.head()
# Out:
# churn     False     True
# state
# AK     0.942308  0.057692
# AL     0.900000  0.100000
# AR     0.800000  0.200000
# AZ     0.937500  0.062500
# CA     0.735294  0.264706

# %%
rate.sort_values(by=True)
# Out:
# churn     False     True
# state
# HI     0.943396  0.056604
# AK     0.942308  0.057692
# AZ     0.937500  0.062500
# VA     0.935065  0.064935
# IA     0.931818  0.068182
# LA     0.921569  0.078431
# NE     0.918033  0.081967
# IL     0.913793  0.086207
# WI     0.910256  0.089744
# RI     0.907692  0.092308
# DC     0.907407  0.092593
# TN     0.905660  0.094340
# WV     0.905660  0.094340
# NM     0.903226  0.096774
# ND     0.903226  0.096774
# AL     0.900000  0.100000
# VT     0.890411  0.109589
# MO     0.888889  0.111111
# WY     0.883117  0.116883
# ID     0.876712  0.123288
# IN     0.873239  0.126761
# FL     0.873016  0.126984
# OH     0.871795  0.128205
# SD     0.866667  0.133333
# KY     0.864407  0.135593
# CO     0.863636  0.136364
# UT     0.861111  0.138889
# OR     0.858974  0.141026
# OK     0.852459  0.147541
# DE     0.852459  0.147541
# GA     0.851852  0.148148
# NH     0.839286  0.160714
# NC     0.838235  0.161765
# CT     0.837838  0.162162
# ...

# %%
#State definitely correlate with target with the highest rate is 26% and the lowest is 5%. 
#I decided to keep "state" columns and drop some unnecessary columns

# %%
unnecessary_cols=['account_length', 'area_code', 'phone_number']

# %%
df.drop(unnecessary_cols, axis=1, inplace=True)

# %%
df.head()
# Out:
#   state  international_plan  voice_mail_plan  number_vmail_messages  \
# 0    KS                   0                1                     25
# 1    OH                   0                1                     26
# 2    NJ                   0                0                      0
# 3    OH                   1                0                      0
# 4    OK                   1                0                      0
#
#    total_day_minutes  total_day_calls  total_day_charge  total_eve_minutes  \
# 0              265.1              110             45.07              197.4
# 1              161.6              123             27.47              195.5
# 2              243.4              114             41.38              121.2
# 3              299.4               71             50.90               61.9
# 4              166.7              113             28.34              148.3
#
#    total_eve_calls  total_eve_charge  total_night_minutes  total_night_calls  \
# ...

# %%
df.churn=df.churn.astype(int)

# %%
df.churn
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: churn, Length: 3333, dtype: int64

# %%
#Checking for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (3333, 18)

# %%
#split data to make it easier on scatter matrix
first=pd.concat([df.iloc[:, 0:8], df.churn], axis=1)
second=df.iloc[:, 8:18]

# %%
pd.plotting.scatter_matrix(first, alpha=0.5, figsize=[20,20])
plt.show()

# %%
pd.plotting.scatter_matrix(second, alpha=0.5, figsize=[20,20])
plt.show()

# %%
#scatter matrix does not help a lot

# %%
#less people churn than did not.
#imbalance data. May need to SMOTE later
sns.countplot(x='churn', data=df)
plt.show()

# %%
state_rate.plot(kind='bar', figsize=[25,10])
plt.show()

# %%
#I want to make it more visualization on state column, please give me some advices

# %% [markdown]
# EDA with Numeric Variables

# %%
df.groupby('churn').total_day_calls.hist(figsize=[12,8]);

# %%
#There are no relationship between churn and total day calls(it is what I see, give me some advice if I am wrong)

# %%
df.groupby('churn').international_plan.plot(kind='hist',figsize=[12,8]);

# %%
# people have international plan mostly churn
#(give me a recomment please, I dont want to see 0.2 0.4 0.6 in my plot. Is there another way to plot?)
